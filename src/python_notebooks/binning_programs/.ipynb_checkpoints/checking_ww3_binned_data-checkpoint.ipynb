# %% [markdown]
# # Check the binning product for WW3

# %% [markdown]
# Plot figure within jupyter notebook

# %%
# %matplotlib inline

# %% [markdown]
# Use the sys library in order to tell the notebook to look for files within the followinf directory path:

# %%
import sys
sys.path.append('/zdata/home/lcolosi/python_functions/')

# %% [markdown]
# Import all libraries and functions

# %%
#libraries
import numpy as np #contains the major of functions used for matrix arrays  
import matplotlib.pyplot as plt # matplotlib contains functions for graphics and plot manipulation
from netCDF4 import Dataset, num2date # netCDF4 handles netCDF files
import glob 
import datetime
from scipy import signal
import cartopy.feature as cfeature
import cmocean.cm as cmo
from matplotlib import cm 

#my functions
from running_mean import running_mean
from save_binned_ww3_hs import save_netcdf_fields_ww3_hs
from save_binned_ww3_wnd import save_netcdf_fields_ww3_wsp
from save_binned_ww3_fp import save_netcdf_fields_ww3_fp
from shift_grid import shift_grid
from mean_temporal_masked_data import mean_mask_t

# %% [markdown]
# Call data from server

# %%
#set filename: 
filename = '/zdata/downloads/colosi_data_bk/binned_data/WW3/CFSR/lc_binned_data/ww3_fp_daily_binned_data_93_16.nc'
#set nc variable in order to read attributes and obtained data: 
nc_wnd = Dataset(filename, 'r')
#call wind speed data
wsp = nc_wnd.variables['fp'][:]
lon = nc_wnd.variables['lon'][:]
lat = nc_wnd.variables['lat'][:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-33b24e5dae80> in <module>
#       4 nc_wnd = Dataset(filename, 'r')
#       5 #call wind speed data
# ----> 6 wsp = nc_wnd.variables['fp'][:]
#       7 lon = nc_wnd.variables['lon'][:]
#       8 lat = nc_wnd.variables['lat'][:]
#
# KeyError: 'fp'

# %% [markdown]
# Check the orientation and shape of the data

# %%
print(wsp.shape)

#plot histogram frequency of data 
plt.figure(figsize=(12,6))
plt.title('WW3 WSP')
plt.pcolor(lon, lat, wsp[8000,:,:], vmin=0, vmax=6, cmap = cm.Greens)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.ylim([-66,66])
cbar = plt.colorbar()
plt.grid()
# Out:
# (8766, 265, 720)

# %%
A
